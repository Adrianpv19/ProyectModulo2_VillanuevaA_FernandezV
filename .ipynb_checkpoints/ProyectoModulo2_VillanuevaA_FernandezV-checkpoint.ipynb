# %% [markdown]
# # Proyecto 2
# ### Integracion Montecarlo
#         Adrian Padilla Villanueva
#         Victor Manuel Vidal Fernández

# %% [markdown]
# # Introduccion
#
# #### En este proyecto aplicaremos los metodos Montecarlo vistos en clase, este metodo tiene diferentes funciones entre ellas esta la funcion de Manejo de Datos, la cual aplicaremos en esta ocasion con el fin de ver como van reaccionando las acciones de las empresas.
#
# #### Nosotros como estudiantes de ingenieria civil, lo utilizaremos para ver el comportamiento de las empresas en la industria de la construcción.

# %% [markdown]
# # Objetivo
#
# Identificar el comportamiento de las acciones de las empresas mexicanas más grandes del país de diferentes sectores en el ámbito de la construcción, para localizar cuales se están viendo menos afectadas y así saber en cual sector es mejor invertir

# %% [markdown]
# Esto lo haremos con la informacion obtenida en Yahoo finance, graficaremos estos datos para ver su comportamiento y asi observar los rendimientos economicos diarios.
#
# Con estos datos podremos determinar cuales son los sectores mas afectados y en cual conviene mas invertir.

# %%
import pandas as pd
import numpy as np
import pandas_datareader.data as web
import matplotlib.pyplot as plt

# %%
def getCloses(names,start,end):
    datos=web.DataReader(names,"yahoo",start,end)
    return datos["Adj Close"]

# %%
names=["ALEATIC.MX","FUNO11.MX","PINFRA.MX"]
start="2018-11-09"
end="2020-11-09"
datos=getCloses(names,start,end)

# %%
datos.plot(grid=True)

# %%
R=datos.pct_change().dropna()
R.describe()
# Out:
# Symbols  ALEATIC.MX   FUNO11.MX   PINFRA.MX
# count    500.000000  500.000000  500.000000
# mean      -0.000279    0.000154   -0.000143
# std        0.012485    0.025863    0.018426
# min       -0.169811   -0.135031   -0.109385
# 25%        0.000000   -0.011028   -0.009258
# 50%        0.000000    0.000603   -0.000677
# 75%        0.000000    0.010248    0.008363
# max        0.112413    0.198851    0.079220

# %%
R.hist(bins=60)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000009BB6148>,
# ...
#       dtype=object)

# %% [markdown]
# ## Rendimientos diarios

# %%
R=(datos-datos.shift())/datos.shift()
R
# Out:
# Symbols     ALEATIC.MX  FUNO11.MX  PINFRA.MX
# Date
# 2018-11-09         NaN        NaN        NaN
# 2018-11-12    0.000000   0.009941  -0.009348
# 2018-11-13   -0.009908  -0.006264  -0.015024
# 2018-11-14    0.000000   0.005853   0.005673
# 2018-11-15    0.000000   0.012534  -0.013092
# ...                ...        ...        ...
# 2020-11-03    0.000000   0.000622   0.021805
# 2020-11-04    0.000000  -0.004353   0.015564
# 2020-11-05    0.000000   0.011243   0.028641
# 2020-11-06    0.000000   0.019840  -0.002764
# 2020-11-09    0.000000   0.068966   0.046174
#
# [501 rows x 3 columns]

# %%
R.plot(grid=True)

# %%
mu=R.mean()
mu
# Out:
# Symbols
# ALEATIC.MX   -0.000279
# FUNO11.MX     0.000154
# PINFRA.MX    -0.000143
# dtype: float64

# %%
std=R.std()
std
# Out:
# Symbols
# ALEATIC.MX    0.012485
# FUNO11.MX     0.025863
# PINFRA.MX     0.018426
# dtype: float64

# %%
def simP(dato,start,ndays,N):
    R=dato.pct_change()
    mu=R.mean()
    std=R.std()
    Rsimulada=np.random.normal(mu,std,(ndays,N))
    fecha=pd.date_range(start,periods=ndays)
    RsimDF=pd.DataFrame(index=fecha,data=Rsimulada)
    Pproyectados=dato[-1]*(RsimDF+1).cumprod()
    return Pproyectados

# %% [markdown]
# # Aleatica - Infraestructura

# %%
Psim=simP(datos['ALEATIC.MX'],'2020-11-09',365,1000)
Psim.plot(legend=False)

# %% [markdown]
# # Aleatica - Infraestructura

# %%
Umbral=datos['ALEATIC.MX'][-1]*1.5
B=Psim>Umbral
Prob=B.mean(axis=1)
Prob.plot(grid=True)

# %% [markdown]
# # Fibra UNO - Servicios Inmobiliarios

# %%
Psim=simP(datos['FUNO11.MX'],'2020-11-09',365,1000)
Psim.plot(legend=False)

# %% [markdown]
# # Fibra UNO - Servicios Inmobiliarios

# %%
Umbral=datos['FUNO11.MX'][-1]*1.5
B=Psim>Umbral
Prob=B.mean(axis=1)
Prob.plot(grid=True)

# %% [markdown]
# # Pinfra - Construccion

# %%
Psim=simP(datos['PINFRA.MX'],'2020-11-09',365,1000)
Psim.plot(legend=False)

# %% [markdown]
# # Pinfra - Construccion

# %%
Umbral=datos['PINFRA.MX'][-1]*1.5
B=Psim>Umbral
Prob=B.mean(axis=1)
Prob.plot(grid=True)

# %% [markdown]
# # Conlusiones
#
# En conclusión descubrimos no es buen momento para invertir en la industria de la construcción, ya que sus probabilidades de que sus acciones se recuperen son casi nulas, esto a causa de que se vieron severamente afectadas por la pandemia del Covid-19.

# %% [markdown]
# # Referencias
#
# https://obras.expansion.mx/construccion/2020/08/20/ranking-las-100-empresas-de-la-construccion-mas-grandes-de-mexico
#
# https://finance.yahoo.com/
